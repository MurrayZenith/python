# %%
msg = "51346"
print(msg)
# Out:
# 51346

# %% [markdown]
# ### wo ui

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
    
plt.plot([1, 2, 3]) 
plt.title(msg) 
plt.draw() 
plt.show()
